# %%
#!python --version
# Out:
# Python 3.10.12

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.3/887.3 kB 32.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r runs/detect/predict /content/drive/My\ Drive/FYP/results
# Out:
# cp: cannot stat 'runs/detect/predict': No such file or directory

# %%
# !yolo settings runs_dir=/content/drive/My\ Drive/FYP/results
# Out:
# JSONDict("/root/.config/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/content/datasets",
#   "weights_dir": "weights",
#   "runs_dir": "/content/drive/My Drive/FYP/results",
#   "uuid": "569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": true,
#   "wandb": false,
#   "vscode_msg": true
# }
# 💡 Learn more about Ultralytics Settings at https://docs.ultralytics.com/quickstart/#ultralytics-settings

# %%
# !yolo settings
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
#!yolo task=detect mode=predict conf=0.25 save=True model="/content/drive/My Drive/FYP/yolov10-main/weights/yolov10x.pt" source="/content/drive/My Drive/FYP/shelf_image.jpeg"
# Out:
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv10x summary (fused): 503 layers, 31,738,160 parameters, 185,184 gradients, 170.6 GFLOPs
#
# image 1/1 /content/drive/My Drive/FYP/shelf_image.jpeg: 448x640 3 58s, 10 73s, 2 75s, 63.7ms
# Speed: 3.4ms preprocess, 63.7ms inference, 30.2ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/drive/My Drive/FYP/results/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
#!yolo task=detect mode=train model="/content/drive/My Drive/FYP/yolov10-main/weights/yolov10x.pt" data="/content/drive/My Drive/FYP/custom_data.yaml" epochs=150 batch=32 plots=True imgsz=416 patience=50 optimizer=AdamW warmup_epochs=5 augment=True mosaic=1.0 amp=True
# Out:
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model="/content/drive/My Drive/FYP/results/detect/train/weights/best.pt" source="/content/drive/My Drive/IMG_7216.mov"
# Out:
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv10x summary (fused): 503 layers, 31,587,932 parameters, 0 gradients, 169.8 GFLOPs
#
# video 1/1 (frame 1/77) /content/drive/My Drive/IMG_7216.mov: 416x320 4 voids, 1312.5ms
# video 1/1 (frame 2/77) /content/drive/My Drive/IMG_7216.mov: 416x320 3 voids, 1263.5ms
# video 1/1 (frame 3/77) /content/drive/My Drive/IMG_7216.mov: 416x320 3 voids, 1246.6ms
# video 1/1 (frame 4/77) /content/drive/My Drive/IMG_7216.mov: 416x320 4 voids, 1190.4ms
# video 1/1 (frame 5/77) /content/drive/My Drive/IMG_7216.mov: 416x320 1 shelf, 4 voids, 1265.5ms
# video 1/1 (frame 6/77) /content/drive/My Drive/IMG_7216.mov: 416x320 4 voids, 1895.0ms
# video 1/1 (frame 7/77) /content/drive/My Drive/IMG_7216.mov: 416x320 1 shelf, 5 voids, 1954.4ms
# video 1/1 (frame 8/77) /content/drive/My Drive/IMG_7216.mov: 416x320 1 shelf, 4 voids, 1569.1ms
# ...
